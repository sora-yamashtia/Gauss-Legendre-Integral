# %%
A = NSolve[
    LegendreP[2^11,x]==0 && x>-1 && x<1,
    x,30]
Export["Legendrezero-11.dat",A]
# Out:
# {{x -> -0.999999310927105329579109685230}, {x -> -0.999996369317744957798874563001},
#
# >   {x -> -0.999991077143972388388493482663}, {x -> -0.999983433242793557274816314489},
#
# >   {x -> -0.999973437488208051671613974963}, {x -> -0.999961089869342048469155210116},
#
# >   {x -> -0.999946390403780367941107912087}, {x -> -0.999929339121414956841538853288},
#
# >   {x -> -0.999909936060152633906389301531}, {x -> -0.999888181264487656323438936934},
#
# >   {x -> -0.999864074784946511222488684143}, {x -> -0.999837616677845294995058672524},
#
# >   {x -> -0.999808807005173654807973672639}, {x -> -0.999777645834535087032847508350},
#
# >   {x -> -0.999744133239114323444056664058}, {x -> -0.999708269297658580460458535816},
#
# >   {x -> -0.999670054094466285322205335451}, {x -> -0.999629487719380017960134273470},
#
# >   {x -> -0.999586570267781921608537931665}, {x -> -0.999541301840590606905918024665},
#
# ...

# %%
A = LegendreP[4,x]
D[A,x]/.x->0.1
# Out:
#         2       4
# 3 - 30 x  + 35 x
# -----------------
#         8
# -0.7325
